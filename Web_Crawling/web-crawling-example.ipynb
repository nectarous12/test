# %% [markdown]
# # 웹 크롤링 selenium 사용 예

# %%
# 라이브러리 불러오기
import pandas as pd
from selenium import webdriver
import time
import math

# %%
# 초기 설정

# 블루베리 시나몬 플렉스 시리얼
url = "https://www.coupang.com/vp/products/29528864?vendorItemId=3222696681&sourceType=SDP_ALSO_VIEWED&rmdId=e4655b075bca4d43a084d2fc95cb46d8&eventLabel=recommendation_widget_pc_sdp_001&platform=web&rmdABTestInfo=9266:C,10242:C,8534:A,8088:A,8091:A,9437:A&rmdValue=p1421463742:vt-1.0.0:p29528864&isAddedCart="

# 페이지 넘길 경우 이미지 등 화면 불러오기 기다리는 시간 단위:초
# 컴퓨터나 네트워크 상황에 따라 너무 빨리 데이터를 가져오면 에러가 발생함. 이런 경우 시간을 늘려야 함.
interval = 2 

# 데이터를 담을 리스트
data_list = []

# %%
driverPath = ".\\webdriver\\chromedriver.exe"

# %%
# 크롬 웹드라이버
driver = webdriver.Chrome(driverPath)  
driver.get(url)
# Out:
# C:\Users\user\anaconda3\envs\multi\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object

# %%
# 상품평 클릭 상품상세에서 상품평으로 이동함. 
driver.find_element_by_css_selector('.count').click()
time.sleep(interval)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-16-857533ecc23a> in <module>
#       1 # 상품평 클릭 상품상세에서 상품평으로 이동함.
# ----> 2 driver.find_element_by_css_selector('.count').click()
#       3 time.sleep(interval)
#
# ~\anaconda3\envs\multi\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_css_selector(self, css_selector)
#     669         """
#     670         warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# --> 671         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     672
#     673     def find_elements_by_css_selector(self, css_selector):
#
# ~\anaconda3\envs\multi\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1092         return self.execute(Command.FIND_ELEMENT, {
#    1093             'using': by,
# -> 1094             'value': value})['value']
#    1095
#    1096     def find_elements(self, by=By.ID, value=None):
#
# ~\anaconda3\envs\multi\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     345         response = self.command_executor.execute(driver_command, params)
#     346         if response:
# --> 347             self.error_handler.check_response(response)
#     348             response['value'] = self._unwrap_value(
#     349                 response.get('value', None))
#
# ~\anaconda3\envs\multi\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     238                 alert_text = value['alert'].get('text')
#     239             raise exception_class(message, screen, stacktrace, alert_text)
# --> 240         raise exception_class(message, screen, stacktrace)
#     241
#     242     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=91.0.4472.124)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00B63733+2504499]
# 	Ordinal0 [0x00AFC401+2081793]
# 	Ordinal0 [0x00A024F0+1058032]
# 	Ordinal0 [0x009F7584+1013124]
# 	Ordinal0 [0x009F7D76+1015158]
# 	Ordinal0 [0x009F94D5+1021141]
# 	Ordinal0 [0x009F35F6+996854]
# 	Ordinal0 [0x00A03830+1062960]
# 	Ordinal0 [0x00A543D2+1393618]
# 	Ordinal0 [0x00A45D4B+1334603]
# 	Ordinal0 [0x00A222B4+1188532]
# 	Ordinal0 [0x00A23149+1192265]
# 	GetHandleVerifier [0x00CDFB8C+1512252]
# 	GetHandleVerifier [0x00D8B0DF+2214031]
# 	GetHandleVerifier [0x00BE4BC3+484211]
# 	GetHandleVerifier [0x00BE3E69+480793]
# 	Ordinal0 [0x00B0218D+2105741]
# 	Ordinal0 [0x00B066E8+2123496]
# 	Ordinal0 [0x00B06827+2123815]
# 	Ordinal0 [0x00B0FB73+2161523]
# 	BaseThreadInitThunk [0x7615FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77C47A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77C47A6E+238]

# %%
# 총 리뷰수 확인
review_total = driver.find_element_by_css_selector('.sdp-review__average__total-star__info-count').text
review_total = review_total.replace(",", "")
review_total

# %%
#페이지별 리뷰 개수
review_per_page = 5

# 전체 페이지 수 계산 리뷰가 9개 일 경우 페이지수는 9 / 5 = 1.8이 나옴
total_page = int(review_total) / review_per_page

# 리뷰가 9개 일 경우 페이지수는 9 / 5 = 1.8 -> 2페이지 올림해야 함. 올림은 ceil
total_page = math.ceil(total_page)

total_page

# %%
# 상품명 확인
product = driver.find_element_by_css_selector('.prod-buy-header__title').text
product

# %%
# 사용자명과 평점 수집 함수 정의
def get_page_data():

    # 사용자명 수집
    users = driver.find_elements_by_css_selector('.sdp-review__article__list__info__user__name.js_reviewUserProfileImage')
    
    # 평점 수집
    ratings = driver.find_elements_by_css_selector('.sdp-review__article__list__info__product-info__star-orange.js_reviewArticleRatingValue')
        
    # 사용자명수와 평점수가 같을 경우만 수집
    if len(users) == len(ratings):            
        for index in range(len(users)):
            data = {}
            data['username'] = users[index].text
            data['rating'] = int(ratings[index].get_attribute('data-rating'))
            print(data)
            data_list.append(data)

# %%
print("수집 시작")

# 첫 페이지 수집하고 시작
get_page_data() 

# 버튼을 눌러서 페이지를 이동해 가면서 계속 수집.
# 예외처리를 해줘야 함. 하지 않으면 중지됨.
for page in range(1, total_page):
    try:
        print(str(page) + " page 수집 끝")

        button_index = page % 10 + 2

        # 데이터 수집이 끝난 뒤 다음 페이지 버튼을 클릭
        driver.find_element_by_xpath('//*[@id="btfTab"]/ul[2]/li[2]/div/div[5]/section[4]/div[3]/button[' + str(button_index) +']').click()
        time.sleep(interval)

        #1 0page 수집이 끝나서 11로 넘어가기 위해서는 > 버튼을 눌러야 함.
        if(page % 10 == 0):
            driver.find_element_by_xpath('//*[@id="btfTab"]/ul[2]/li[2]/div/div[5]/section[4]/div[3]/button[12]').click()
            time.sleep(interval)

        # 해당 페이지 데이터 수집 
        get_page_data()
    except:
        print("수집 에러")

print(str(page) + " page 수집 끝")
print("수집 종료")

# %%
df = pd.DataFrame(data_list)

# %%
# 엑셀로 저장
df.to_excel("coupang-crawling-example.xlsx")

# %% [markdown]
# # 전체 코드

# %%
# 라이브러리 불러오기
import pandas as pd
from selenium import webdriver
import time
import math

# 초기 설정

# 블루베리 시나몬 플렉스 시리얼
url = "https://www.coupang.com/vp/products/29528864?vendorItemId=3222696681&sourceType=SDP_ALSO_VIEWED&rmdId=e4655b075bca4d43a084d2fc95cb46d8&eventLabel=recommendation_widget_pc_sdp_001&platform=web&rmdABTestInfo=9266:C,10242:C,8534:A,8088:A,8091:A,9437:A&rmdValue=p1421463742:vt-1.0.0:p29528864&isAddedCart="

# 페이지 넘길 경우 이미지 등 화면 불러오기 기다리는 시간 단위:초
# 컴퓨터나 네트워크 상황에 따라 너무 빨리 데이터를 가져오면 에러가 발생함. 이런 경우 시간을 늘려야 함.
interval = 2 

# 데이터를 담을 리스트
data_list = []

# 크롬 웹드라이버
driver = webdriver.Chrome("./chromedriver")  
driver.get(url)   
time.sleep(interval)

# 상품평 클릭 상품상세에서 상품평으로 이동함. 
driver.find_element_by_css_selector('.count').click()
time.sleep(interval)

# 총 리뷰수 확인
review_total = driver.find_element_by_css_selector('.sdp-review__average__total-star__info-count').text
review_total = review_total.replace(",", "")
print(review_total)

#페이지별 리뷰 개수
review_per_page = 5

# 전체 페이지 수 계산 리뷰가 9개 일 경우 페이지수는 9 / 5 = 1.8이 나옴
total_page = int(review_total) / review_per_page

# 리뷰가 9개 일 경우 페이지수는 9 / 5 = 1.8 -> 2페이지 올림해야 함. 올림은 ceil
total_page = math.ceil(total_page)
print(total_page)

# 상품명 확인
product = driver.find_element_by_css_selector('.prod-buy-header__title').text
print(product)

# 사용자명과 평점 수집 함수 정의
def get_page_data():

    # 사용자명 수집
    users = driver.find_elements_by_css_selector('.sdp-review__article__list__info__user__name.js_reviewUserProfileImage')
    
    # 평점 수집
    ratings = driver.find_elements_by_css_selector('.sdp-review__article__list__info__product-info__star-orange.js_reviewArticleRatingValue')
        
    # 사용자명수와 평점수가 같을 경우만 수집
    if len(users) == len(ratings):            
        for index in range(len(users)):
            data = {}
            data['username'] = users[index].text
            data['rating'] = int(ratings[index].get_attribute('data-rating'))
            print(data)
            data_list.append(data)
            
print("수집 시작")

# 첫 페이지 수집하고 시작
get_page_data() 

# 버튼을 눌러서 페이지를 이동해 가면서 계속 수집.
# 예외처리를 해줘야 함. 하지 않으면 중지됨.
for page in range(1, total_page):
    try:
        print(str(page) + " page 수집 끝")

        button_index = page % 10 + 2

        # 데이터 수집이 끝난 뒤 다음 페이지 버튼을 클릭
        driver.find_element_by_xpath('//*[@id="btfTab"]/ul[2]/li[2]/div/div[5]/section[4]/div[3]/button[' + str(button_index) +']').click()
        time.sleep(interval)

        #1 0page 수집이 끝나서 11로 넘어가기 위해서는 > 버튼을 눌러야 함.
        if(page % 10 == 0):
            driver.find_element_by_xpath('//*[@id="btfTab"]/ul[2]/li[2]/div/div[5]/section[4]/div[3]/button[12]').click()
            time.sleep(interval)

        # 해당 페이지 데이터 수집 
        get_page_data()
    except:
        print("수집 에러")

print(str(page) + " page 수집 끝")
print("수집 종료")
    
df = pd.DataFrame(data_list)
print(df)

# 엑셀로 저장
df.to_excel("coupang-crawling-example.xlsx")
# Out:
# 206
# 42
# 네이쳐패스 블루베리 시나몬 플렉스 시리얼
# 수집 시작
# {'username': '웅장해진다 ', 'rating': 5}
# {'username': '배*웅 ', 'rating': 2}
# {'username': '김*람 ', 'rating': 5}
# {'username': '박*름 ', 'rating': 5}
# {'username': '팜*늉 ', 'rating': 5}
# 1 page 수집 끝
# {'username': '집콕하쥬 ', 'rating': 5}
# {'username': '신*경 ', 'rating': 3}
# {'username': '김*정 ', 'rating': 5}
# {'username': '장*우 ', 'rating': 4}
# {'username': '과자중독자 ', 'rating': 5}
# 2 page 수집 끝
# {'username': '정*란 ', 'rating': 5}
# {'username': '박*연 ', 'rating': 5}
# {'username': '이*진 ', 'rating': 5}
# {'username': '이*연 ', 'rating': 4}
# {'username': '사*현 ', 'rating': 5}
# 3 page 수집 끝
# {'username': '김*옥 ', 'rating': 5}
# {'username': '김*옥 ', 'rating': 5}
# {'username': '이*수 ', 'rating': 5}
# {'username': '함*지 ', 'rating': 5}
# {'username': '건강한살림 ', 'rating': 5}
# 4 page 수집 끝
# {'username': 'haisue ', 'rating': 5}
# {'username': '최*진 ', 'rating': 4}
# {'username': '김*옥 ', 'rating': 3}
# {'username': '건강한살림 ', 'rating': 5}
# {'username': '홍*지 ', 'rating': 5}
# 5 page 수집 끝
# {'username': '김보통 ', 'rating': 5}
# {'username': '백*희 ', 'rating': 4}
# {'username': '이*연 ', 'rating': 4}
# {'username': '장*정 ', 'rating': 3}
# {'username': '배*녹 ', 'rating': 5}
# 6 page 수집 끝
# {'username': '윤*정 ', 'rating': 5}
# {'username': '백*나 ', 'rating': 3}
# {'username': '이*경 ', 'rating': 5}
# {'username': '최*수 ', 'rating': 5}
# {'username': '탈*원 ', 'rating': 5}
# 7 page 수집 끝
# {'username': '노*헌 ', 'rating': 5}
# {'username': '이*근 ', 'rating': 5}
# {'username': '아이야앙 ', 'rating': 5}
# {'username': '변*욱 ', 'rating': 5}
# {'username': '한*주 ', 'rating': 4}
# 8 page 수집 끝
# {'username': '오*솔 ', 'rating': 5}
# {'username': '김*영 ', 'rating': 4}
# {'username': '김*화 ', 'rating': 3}
# {'username': '전*진 ', 'rating': 5}
# {'username': 'geon ', 'rating': 3}
# 9 page 수집 끝
# {'username': '임*빈 ', 'rating': 3}
# {'username': '유*진 ', 'rating': 4}
# {'username': '이*준 ', 'rating': 3}
# {'username': '최*화 ', 'rating': 5}
# {'username': '배*연 ', 'rating': 5}
# 10 page 수집 끝
# {'username': '이*원 ', 'rating': 5}
# {'username': '서*남 ', 'rating': 3}
# {'username': '김*미 ', 'rating': 4}
# {'username': '김*인 ', 'rating': 5}
# {'username': '박*리 ', 'rating': 5}
# 11 page 수집 끝
# {'username': 'K*a ', 'rating': 5}
# {'username': '문*용 ', 'rating': 2}
# {'username': '김*아 ', 'rating': 4}
# {'username': '박*원 ', 'rating': 5}
# {'username': '김*은 ', 'rating': 3}
# 12 page 수집 끝
# {'username': '신*호 ', 'rating': 4}
# {'username': '이*나 ', 'rating': 3}
# {'username': '영보 ', 'rating': 4}
# {'username': '조*미 ', 'rating': 5}
# {'username': '옥*윤 ', 'rating': 5}
# 13 page 수집 끝
# {'username': '오*진 ', 'rating': 5}
# {'username': '백*희 ', 'rating': 5}
# {'username': '이*주 ', 'rating': 3}
# {'username': '손*름 ', 'rating': 4}
# {'username': '이*영 ', 'rating': 1}
# 14 page 수집 끝
# {'username': '김*영 ', 'rating': 5}
# {'username': '유*은 ', 'rating': 5}
# {'username': 'y*n ', 'rating': 3}
# {'username': '김*인 ', 'rating': 5}
# {'username': '김*연 ', 'rating': 5}
# 15 page 수집 끝
# {'username': '백*희 ', 'rating': 5}
# {'username': '송*주 ', 'rating': 1}
# {'username': '김*숙 ', 'rating': 5}
# {'username': '임*석 ', 'rating': 3}
# {'username': '박*미 ', 'rating': 5}
# 16 page 수집 끝
# {'username': 'K*a ', 'rating': 5}
# {'username': '팩트싸대기 ', 'rating': 1}
# {'username': '배*은 ', 'rating': 5}
# {'username': '백*희 ', 'rating': 5}
# {'username': '김*리 ', 'rating': 5}
# 17 page 수집 끝
# {'username': 'haisue ', 'rating': 5}
# {'username': '옥*윤 ', 'rating': 5}
# {'username': '장*원 ', 'rating': 5}
# {'username': '신*정 ', 'rating': 5}
# {'username': '손*목 ', 'rating': 3}
# 18 page 수집 끝
# {'username': '강*은 ', 'rating': 4}
# {'username': '이*숙 ', 'rating': 5}
# {'username': '천*주 ', 'rating': 3}
# {'username': '시나몬 ', 'rating': 3}
# {'username': '김*인 ', 'rating': 5}
# 19 page 수집 끝
# {'username': 'K*a ', 'rating': 5}
# {'username': '목*정 ', 'rating': 5}
# {'username': '김*인 ', 'rating': 5}
# {'username': '신*리 ', 'rating': 1}
# {'username': '박*민 ', 'rating': 1}
# 20 page 수집 끝
# {'username': '김*연 ', 'rating': 5}
# {'username': '수니님du ', 'rating': 2}
# {'username': '김*옥 ', 'rating': 5}
# {'username': '백*학 ', 'rating': 4}
# {'username': 'taylo ', 'rating': 3}
# 21 page 수집 끝
# {'username': '이* ', 'rating': 2}
# {'username': '유*은 ', 'rating': 5}
# {'username': '양*원 ', 'rating': 5}
# {'username': '신*령 ', 'rating': 5}
# {'username': '배*영 ', 'rating': 5}
# 22 page 수집 끝
# {'username': '박*희 ', 'rating': 2}
# {'username': '임*현 ', 'rating': 4}
# {'username': '박*미 ', 'rating': 4}
# {'username': '은*래 ', 'rating': 5}
# {'username': '박*휘 ', 'rating': 4}
# 23 page 수집 끝
# {'username': '정*호 ', 'rating': 5}
# {'username': '김*언 ', 'rating': 5}
# {'username': 'haisue ', 'rating': 5}
# {'username': '김*은 ', 'rating': 3}
# {'username': '박*니 ', 'rating': 5}
# 24 page 수집 끝
# {'username': '장*원 ', 'rating': 5}
# {'username': '백*은 ', 'rating': 1}
# {'username': '영보 ', 'rating': 4}
# {'username': '원*숙 ', 'rating': 5}
# {'username': '천*주 ', 'rating': 3}
# 25 page 수집 끝
# {'username': '박*미 ', 'rating': 4}
# {'username': '신*주 ', 'rating': 5}
# {'username': '초코아이스 ', 'rating': 4}
# {'username': '대악마 ', 'rating': 2}
# {'username': '김*영 ', 'rating': 2}
# 26 page 수집 끝
# {'username': '손*경 ', 'rating': 3}
# {'username': '쿠팡실구매자 ', 'rating': 4}
# {'username': 'R*W ', 'rating': 5}
# {'username': 'R*W ', 'rating': 5}
# {'username': '장*진 ', 'rating': 1}
# 27 page 수집 끝
# {'username': '이*희 ', 'rating': 5}
# {'username': 'A*N ', 'rating': 5}
# {'username': '담화린1 ', 'rating': 5}
# {'username': '문*용 ', 'rating': 4}
# {'username': '김*화 ', 'rating': 5}
# 28 page 수집 끝
# {'username': '문*용 ', 'rating': 3}
# {'username': '문*용 ', 'rating': 4}
# {'username': '임*하 ', 'rating': 5}
# {'username': '문*용 ', 'rating': 3}
# {'username': '파미맘 ', 'rating': 4}
# 29 page 수집 끝
# {'username': '송*우 ', 'rating': 5}
# {'username': '김*훈 ', 'rating': 4}
# {'username': '김*현 ', 'rating': 5}
# {'username': '뉴바이블 ', 'rating': 5}
# {'username': '이*희 ', 'rating': 5}
# 30 page 수집 끝
# {'username': '이*원 ', 'rating': 5}
# {'username': '장*암 ', 'rating': 5}
# {'username': '문*미 ', 'rating': 5}
# {'username': '체지방감량 ', 'rating': 5}
# {'username': '송*진 ', 'rating': 5}
# 31 page 수집 끝
# {'username': '송*진 ', 'rating': 5}
# {'username': 'P*A ', 'rating': 5}
# {'username': '조용환 ', 'rating': 5}
# {'username': '이*흔 ', 'rating': 3}
# {'username': '정*윤 ', 'rating': 3}
# 32 page 수집 끝
# {'username': '황*희 ', 'rating': 3}
# {'username': '황*경 ', 'rating': 5}
# {'username': '방*정 ', 'rating': 3}
# {'username': '열린 ', 'rating': 4}
# {'username': '박*림 ', 'rating': 5}
# 33 page 수집 끝
# {'username': '조*식 ', 'rating': 4}
# {'username': '장*주 ', 'rating': 5}
# {'username': 'A*O ', 'rating': 5}
# {'username': '이*영 ', 'rating': 5}
# {'username': 'Vegan ', 'rating': 5}
# 34 page 수집 끝
# {'username': '김*선 ', 'rating': 5}
# {'username': '담화린1 ', 'rating': 5}
# {'username': '담화린1 ', 'rating': 5}
# {'username': '정*미 ', 'rating': 4}
# {'username': '김*희 ', 'rating': 4}
# 35 page 수집 끝
# {'username': '김*경 ', 'rating': 3}
# {'username': '김*인 ', 'rating': 5}
# {'username': '박*은 ', 'rating': 3}
# {'username': '이* ', 'rating': 5}
# {'username': '탈*원 ', 'rating': 5}
# 36 page 수집 끝
# {'username': '임*경 ', 'rating': 5}
# {'username': '서*희 ', 'rating': 5}
# {'username': '김*현 ', 'rating': 5}
# {'username': 'A*e ', 'rating': 5}
# {'username': '신*령 ', 'rating': 5}
# 37 page 수집 끝
# {'username': '멍구눈 ', 'rating': 4}
# {'username': 'sezane ', 'rating': 1}
# {'username': '서*희 ', 'rating': 5}
# {'username': '김*희 ', 'rating': 3}
# {'username': '방*희 ', 'rating': 1}
# 38 page 수집 끝
# {'username': 'W*S ', 'rating': 5}
# {'username': '우*욱 ', 'rating': 5}
# {'username': '정*균 ', 'rating': 5}
# {'username': '한*진 ', 'rating': 5}
# {'username': '정*혜 ', 'rating': 5}
# 39 page 수집 끝
# {'username': '윤*경 ', 'rating': 3}
# {'username': '박*원 ', 'rating': 1}
# {'username': '오*진 ', 'rating': 4}
# {'username': '장*영 ', 'rating': 5}
# {'username': '조*옥 ', 'rating': 5}
# 40 page 수집 끝
# {'username': '유*라 ', 'rating': 5}
# {'username': '김*애 ', 'rating': 3}
# {'username': '배*현 ', 'rating': 5}
# {'username': 'L*A ', 'rating': 5}
# {'username': '배*현 ', 'rating': 5}
# 41 page 수집 끝
# {'username': '정*영 ', 'rating': 2}
# 41 page 수집 끝
# 수집 종료
#     username  rating
# 0     웅장해진다        5
# 1       배*웅        2
# 2       김*람        5
# 3       박*름        5
# 4       팜*늉        5
# ..       ...     ...
# 201     김*애        3
# 202     배*현        5
# 203     L*A        5
# 204     배*현        5
# 205     정*영        2
#
# [206 rows x 2 columns]
