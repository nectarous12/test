# %%
import time
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver as wd

## CHECK START TIME
start = time.time()       # 시작 시간 (전체 수행시간을 구하기 위함)

browser = webdriver.Chrome(r"D:\chromedriver.exe")

# INPUT YOUTUBE URL
url = "https://www.youtube.com/watch?v=F7rH4tziJs0"       # 댓글 수집할 Youtube URL입력
browser.get(url)

last_page_height = browser.execute_script("return document.documentElement.scrollHeight")

while True:
    browser.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(1.0)       # 인터발 1이상으로 줘야 데이터 취득가능(롤링시 데이터 로딩 시간 때문)
    new_page_height = browser.execute_script("return document.documentElement.scrollHeight")

    if new_page_height == last_page_height:
        break
    last_page_height = new_page_height

html_source = browser.page_source
browser.close()

# %%
soup = BeautifulSoup(html_source, "lxml")

youtube_user_IDs = soup.select("div#header-author > h3 > a > span")
youtube_comments = soup.select("yt-formatted-string#content-text")

# %%
youtube_user_IDs
# Out:
# [<span class="channel-owner style-scope ytd-comment-renderer">
#                달라스튜디오
#              </span>,
#  <span class="style-scope ytd-comment-renderer">
#                홍성오빠 hongseongobba
#              </span>,
#  <span class="style-scope ytd-comment-renderer">
#                이현주
#              </span>,
#  <span class="style-scope ytd-comment-renderer">
#                渡辺chris
#              </span>,
#  <span class="style-scope ytd-comment-renderer">
#                CR Kim
#              </span>,
#  <span class="style-scope ytd-comment-renderer">
#                eorjs Lee
#              </span>,
#  <span class="style-scope ytd-comment-renderer">
#                한송이
#              </span>,
#  <span class="style-scope ytd-comment-renderer">
#                JH NO
#              </span>,
#  <span class="style-scope ytd-comment-renderer">
#                November Nine
#              </span>,
#  <span class="style-scope ytd-comment-renderer">
#                꾸돌
# ...

# %%
str_youtube_userIDs = []   # USER ID 배열
str_youtube_comments = []  # USER 댓글 내용 배열

# REPLACE DATA
for i in range(len(youtube_user_IDs)):
    str_tmp = str(youtube_user_IDs[i].text)
    str_tmp = str_tmp.replace('\n', '')
    str_tmp = str_tmp.replace('\t', '')
    str_tmp = str_tmp.replace('   ','')
    str_youtube_userIDs.append(str_tmp)

    str_tmp = str(youtube_comments[i].text)
    str_tmp = str_tmp.replace('\n', '')
    str_tmp = str_tmp.replace('\t', '')
    str_tmp = str_tmp.replace('   ','')
    str_youtube_comments.append(str_tmp)

# %%
str_youtube_comments
# Out:
# ['국룰조합 조지러 가자💨👉 편의점 네고 계약서는 커뮤니티탭으로 ㄱㄱ',
#  '6시내고왕ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '최 : 최초의 편의점이 무슨 소용경 : 경쟁사는 나날이 발전하는데호 : 호구잡힐 소비자도 이제 없으니 반성하세요',
#  '그냥 존나 바보 같음ㅋㅋㅋ고객이 원하는 것도 모르고 세상이 어떻게 흘러가는지도 모르는 듯',
#  '제일 별로인건 직원들이 거짓말하는거.... 진짜 신뢰안간다 ㅠㅠ',
#  '다른건 모르겠고 삼각김밥 내용물 많다하고 우기는거 진짜 짜증났음ㅋㅋㅋㅋ양심이 없으신건가 아님 진짜 세뇌야 뭐야...',
#  '아니 이럴거면 네고왕을 왜찍음? 회사가 진정성도 없고 완전 자만심에 빠진거 완전 느껴짐,,, 뻔히 사전조사 다하고 온거 아는데 삼각김밥 토핑 젤 많다고 그게 웃긴컵셉인가?영란언니만 추운날 고생한거 안쓰럽다,,',
#  'CU : 그냥 가는 편의점 / GS : 도시락 먹으러가는 편의점 / 미니스톱 : 소프트 아이스크림 먹으러 가는 편의점 / 7-11 : 주변에 아무것도 없을때 가는 편의점',
#  '진심 세븐일레븐이 편의점중에 삼각김밥 제일 구린거 공공연한 사실인데 세븐일레븐이 제일많다고 팩트라고 이러는거 진짜 .. 할많하않..',
#  '뭐 전부 다 안된대 표정썩어가며...ㅋㅋㅋ약간 소통안되는 찐꼰머인듯....저럴거면 왜하는건가 보는데 진짜개불편하네영란누나도 엄청뻘쭘했을듯....ㅜㅜ',
#  '직장 분위기 ㄹㅇ 사이비 같네 ㅋㅋ 저러니까 망하지',
#  '이거 보니까 스킨푸드가 얼마나 진심이었는지 알겠네.. 스킨푸드 네고 끝나고도 계속 구매해서 쓰는중임',
#  '올드한 이미지만 갖고 있는게 아니라그냥 회사 자체가 올드하네타 브랜드 편의점 수에 비해세븐 일레븐만 줄어든 이유를 알겠네',
# ...

# %%
str_youtube_userIDs
# Out:
# ['  달라스튜디오',
#  '  홍성오빠 hongseongobba',
#  '  이현주',
#  '  渡辺chris',
#  '  CR Kim',
#  '  eorjs Lee',
#  '  한송이',
#  '  JH NO',
#  '  November Nine',
#  '  꾸돌',
#  '  이민혁',
#  '  oh yoon',
#  '  도넛',
#  '  국립중앙방구석',
#  '  Rowa',
#  '  냠냠치킨',
#  '  장민석',
#  '  koolpiss',
#  '  Sangwon Park',
#  '  System •',
#  '  JaeHwang Jeff Lee',
#  '  o o',
#  '  김승현',
#  '  Ex Fl',
#  '  유건우',
#  '  따라란',
#  '  sarada',
#  '  김예슬',
#  '  명순조',
#  '  산딸기주스',
#  '  해인',
#  '  코코몽',
#  '  이원희',
#  '  랑이',
#  '  Ethan Hunt',
#  '  태키',
#  '  멍멍',
#  '  바람',
#  '  박선아',
#  '  밥',
#  '  아몰랑',
#  '  자성',
#  '  이성협',
#  '  팔레트',
#  '  BA 201',
#  '  조원',
#  '  크앙',
#  '  김대륙',
#  '  수짇수',
#  '  양프로',
#  '  스톤하',
#  '  김유림',
#  '  장여사',
#  '  lur b',
#  '  Mmin M',
#  '  짱구군',
#  '  이밤',
#  '  PANG PANG',
#  '  심바',
#  '  WO',
#  '  CHEF KIM',
#  '  h k',
#  '  퓨처',
#  '  백원짜리빵',
#  '  냠냠치킨',
#  '  ssun park',
#  '  블랙빈',
#  '  maso',
#  '  정수',
#  '  유예나',
#  '  서리',
#  '  핑쿠르트',
#  '  원',
# ...

# %%
## MODIFY VIEW FORMAT
pd_data = {"ID":str_youtube_userIDs, "comment":str_youtube_comments}
youtube_pd = pd.DataFrame(pd_data)

# %%
## WRITE TO EXCEL
youtube_pd.to_excel("D:\data.xlsx", sheet_name="sheet1", index=True)
print("Running Time : ", time.time() - start)       # 전체 수행 시킨 출력
# Out:
# Running Time :  227.48001098632812
