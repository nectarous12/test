# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df=pd.read_csv('tips.csv')

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
tips=df

# %%
sns.regplot(x="total_bill",y="tip",data=tips);

# %%
sns.displot(data=tips, x="smoker", hue="smoker")

# %%
sns.displot(data=tips, x="sex", hue="smoker")

# %%
sns.displot(data=tips, x="day", hue="day")

# %%
sns.scatterplot(x='total_bill', y='tip', hue="sex", data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-5251dffdb860> in <module>
# ----> 1 sns.scatterplot(x='flipper_length_mm', y='tip', hue="sex", data=tips)
#
# ~\anaconda3\envs\multi\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\envs\multi\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     803         x_bins=x_bins, y_bins=y_bins,
#     804         estimator=estimator, ci=ci, n_boot=n_boot,
# ...

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins.groupby('species').count()
# Out:
#            island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species
# Adelie        152             151            151                151
# Chinstrap      68              68             68                 68
# Gentoo        124             123            123                123
#
#            body_mass_g  sex
# species
# Adelie             151  146
# Chinstrap           68   68
# Gentoo             123  119

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.scatterplot(x='flipper_length_mm', y='body_mass_g', hue="sex", data=penguins)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.kdeplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", col="species")
